# %%
import numpy as np
import pandas as pd
import pickle
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()

# %%
fileName        = '/Users/chanaross/dev/Thesis/UberData/manhattenData_DenseGrid_5min_pickle.p'
dataMan   = np.load(fileName)

# %%
dataMan
# Out:
#                Lat        Lon    Base           TimeStamp  weekday  weeknum  \
# 0       -16.419431 -83.775757  B02512 2014-04-01 00:11:00        1       14
# 2       -16.452091 -83.779900  B02512 2014-04-01 00:21:00        1       14
# 3       -16.434939 -83.788089  B02512 2014-04-01 00:28:00        1       14
# 4       -16.432091 -83.784079  B02512 2014-04-01 00:33:00        1       14
# 6       -16.457044 -83.775552  B02512 2014-04-01 00:39:00        1       14
# 7       -16.434131 -83.791106  B02512 2014-04-01 00:45:00        1       14
# 8       -16.446648 -83.799185  B02512 2014-04-01 00:55:00        1       14
# 9       -16.438870 -83.792979  B02512 2014-04-01 01:01:00        1       14
# 10      -16.454666 -83.776042  B02512 2014-04-01 01:19:00        1       14
# 11      -16.430421 -83.780832  B02512 2014-04-01 01:48:00        1       14
# 12      -16.450833 -83.771593  B02512 2014-04-01 01:49:00        1       14
# ...

# %%
averageData = []
numPerWeek = []
for j in range(dataMan['weekPeriod5'].unique()):
    for i in range(dataMan['weeknum'].unique()):
        numPerWeek.append(dataMan[(dataMan['weekPeriod5']==10) & (dataMan['weeknum'] == 18)].size)
    averageData.append([j,np.mean(numPerWeek)]
print(averageData)
# Out:
#   File "<ipython-input-32-98cb00c6db3a>", line 7
#     print(averageData)
#         ^
# SyntaxError: invalid syntax

# %%
dataMan[(dataMan['weekPeriod5']==10) & (dataMan['weeknum'] == 18)]
# Out:
#               Lat        Lon    Base           TimeStamp  weekday  weeknum  \
# 191103 -16.453303 -83.779626  B02598 2014-04-28 00:50:00        0       18
# 527205 -16.473105 -83.791567  B02682 2014-04-28 00:50:00        0       18
# 527207 -16.446333 -83.800296  B02682 2014-04-28 00:51:00        0       18
# 527208 -16.426727 -83.776346  B02682 2014-04-28 00:52:00        0       18
# 527209 -16.453407 -83.784876  B02682 2014-04-28 00:52:00        0       18
# 527210 -16.473834 -83.785535  B02682 2014-04-28 00:54:00        0       18
#
#         month  hour  minute  weekPeriod  dayQuad             x             y  \
# 191103      4     0      50           3        0 -9.326305e+06 -1.857278e+06
# 527205      4     0      50           3        0 -9.327635e+06 -1.859577e+06
# 527207      4     0      51           3        0 -9.328606e+06 -1.856469e+06
# 527208      4     0      52           3        0 -9.325940e+06 -1.854193e+06
# ...
